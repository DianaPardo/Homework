# %%
import time
import re
from bs4 import BeautifulSoup as bs
from splinter import Browser
import pandas as pd
import requests
from selenium import webdriver

# %%
executable_path = {"executable_path": "chromedriver"}
browser = Browser("chrome", **executable_path, headless=True)
url = 'http://www.fhfa.gov/DataTools/Tools/Pages/House-Price-Index-(HPI).aspx'
browser.visit(url)
html = browser.html
soup = bs(html, 'html.parser')

# %%
maidMoneyTable = soup.find_all(id='divHPITableChart')

# %%
print(maidMoneyTable)
# Out:
# [<div id="divHPITableChart"><div class="google-visualization-table" style="position: relative; z-index: 0; max-width: 100%; max-height: 100%;"><div style="position: relative; overflow: auto; max-width: 100%; max-height: 100%;"><table cellspacing="0" class="google-visualization-table-table"><thead><tr class="tc-tableHeaderRow"><th class="google-visualization-table-th gradient unsorted">State<span class="google-visualization-table-sortind"></span></th><th class="google-visualization-table-th gradient sort-ascending">Rank<span class="google-visualization-table-sortind"></span></th><th class="google-visualization-table-th gradient unsorted">1-Quarter<span class="google-visualization-table-sortind"></span></th><th class="google-visualization-table-th gradient unsorted">1-Year<span class="google-visualization-table-sortind"></span></th><th class="google-visualization-table-th gradient unsorted">5-Years<span class="google-visualization-table-sortind"></span></th><th class="google-visualization-table-th gradient unsorted">Since 1991Q1<span class="google-visualization-table-sortind"></span></th></tr></thead><tbody><tr class="tc-tableRow"><td class="google-visualization-table-td">District of Columbia</td><td class="google-visualization-table-td google-visualization-table-td-number">1</td><td class="google-visualization-table-td google-visualization-table-td-number">4.48</td><td class="google-visualization-table-td google-visualization-table-td-number">14.29</td><td class="google-visualization-table-td google-visualization-table-td-number">53.32</td><td class="google-visualization-table-td google-visualization-table-td-number">461.62</td></tr><tr class="tc-oddTableRow"><td class="google-visualization-table-td">Washington</td><td class="google-visualization-table-td google-visualization-table-td-number">2</td><td class="google-visualization-table-td google-visualization-table-td-number">2.82</td><td class="google-visualization-table-td google-visualization-table-td-number">12.04</td><td class="google-visualization-table-td google-visualization-table-td-number">56.52</td><td class="google-visualization-table-td google-visualization-table-td-number">244.28</td></tr><tr class="tc-tableRow"><td class="google-visualization-table-td">Idaho</td><td class="google-visualization-table-td google-visualization-table-td-number">3</td><td class="google-visualization-table-td google-visualization-table-td-number">3.71</td><td class="google-visualization-table-td google-visualization-table-td-number">11.49</td><td class="google-visualization-table-td google-visualization-table-td-number">48.85</td><td class="google-visualization-table-td google-visualization-table-td-number">202.64</td></tr><tr class="tc-oddTableRow"><td class="google-visualization-table-td">Nevada</td><td class="google-visualization-table-td google-visualization-table-td-number">4</td><td class="google-visualization-table-td google-visualization-table-td-number">4.63</td><td class="google-visualization-table-td google-visualization-table-td-number">11.45</td><td class="google-visualization-table-td google-visualization-table-td-number">81.84</td><td class="google-visualization-table-td google-visualization-table-td-number">139.02</td></tr><tr class="tc-tableRow"><td class="google-visualization-table-td">Utah</td><td class="google-visualization-table-td google-visualization-table-td-number">5</td><td class="google-visualization-table-td google-visualization-table-td-number">2.70</td><td class="google-visualization-table-td google-visualization-table-td-number">10.74</td><td class="google-visualization-table-td google-visualization-table-td-number">46.03</td><td class="google-visualization-table-td google-visualization-table-td-number">286.26</td></tr><tr class="tc-oddTableRow"><td class="google-visualization-table-td">Colorado</td><td class="google-visualization-table-td google-visualization-table-td-number">6</td><td class="google-visualization-table-td google-visualization-table-td-num ...
